# %%
import random
 
maxTicketsAvailable = int(input("Enter the maximum tickets available - "))
 
participants = []
 
for temp in range(maxTicketsAvailable):
  st = "Enter the Participant name - "+ str(temp + 1) + " - "
  name = input(st)
  participants.append(name)
 
print("All of theparticipants in the lottery ticket - ",participants)
 
n = random.randint(0,maxTicketsAvailable-1)
 
print("Winner of the lottery ticket - ",participants[n])
# Out:
# Enter the maximum tickets available - 3
# Enter the Participant name - 1 - Ramya
# Enter the Participant name - 2 - Raksha
# Enter the Participant name - 3 - Chandra
# All of theparticipants in the lottery ticket -  ['Ramya', 'Raksha', 'Chandra']
# Winner of the lottery ticket -  Raksha
